# %% [markdown]
# ## Report: act_report
#
# > **by EMMANUEL NCUBE**
#
# ## Introduction
#
# This report is part of the fulfillment of the Udacity Data Science Nanodegree, and aims to present relevant insights from the [WeRateDogs](https://twitter.com/dog_rates) twitter account.
#
# <img src="https://pbs.twimg.com/profile_banners/4196983835/1661991479/1500x500" alt="A dog" style="width:800px;"/>
#
# [WeRateDogs](https://twitter.com/dog_rates) is a twitter account that rates people's dogs with a humorous comment about the dog. The account was started in 2015 by college student Matt Nelson, and has received international media attention for its popularity.[WeRateDogs](https://twitter.com/dog_rates) asks people to send photos of their dogs, then tweets selected photos rating and a humorous comment. Dogs are rated on a scale of one to ten, but are invariably given ratings in excess of the maximum, such as "13/10". Popular posts are re-posted on Instagram and Facebook. Check more information [here](https://en.wikipedia.org/wiki/WeRateDogs).
#
# The data from [WeRateDogs](https://twitter.com/dog_rates) twitter archive was collected and cleaned. A summary [Data Wrangle Report](https://viewf6b31853.udacity-student-workspaces.com/view/wrangle_report.html) was also prepared. The main partly clean dataset for this analysis is a csv file named [twitter_archive_master](https://viewf6b31853.udacity-student-workspaces.com/edit/twitter_archive_master.csv) which is a combination three datasets; archive_clean_master.csv, image_predictions_master.csv and tweets clean.

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %% [markdown]
# ### 1. The top 5 popular dog names
# If you plan to join the ranks of pet owners across America, then you'll be faced with the important decision of choosing the perfect name for your dog.Here are the top 5 popular dog names, as shown in Fig. 1 below,;
# > 1. Charlie
# 2. Cooper
# 3. Oliver
# 4. Lucy
# 5. Sadie.
#
# This was confirmed by Martha Stewart in her article [The Most Popular Dog Names and the Meanings Behind Each of Them](https://www.marthastewart.com/8101515/popular-dog-name-meanings).

# %%
from IPython import display
display.Image("./images/dog_name.png")

# %% [markdown]
# ### 2. Highly retweeted and favorite dog stage.
#
# > Averagely, puppos are the most retweeted and favorite dog stage as shown in Fig. 2. A puppo is a transitional phase between pupper and doggo. According to an article [**10 REASONS WHY YOU SHOULD GET A PUPPY**](https://blog.tryfi.com/10-reasons-why-you-should-get-a-puppy/#:~:text=Puppies%20teach%20responsibility.&text=Adopting%20a%20puppy%20can%20help,be%20their%20first%20best%20friend.) by PURINA, there is *"....a connection between spending time with your dog and feeling more relaxed and less stressed*".

# %%
display.Image("./images/favorite_retweet.png", embed=True, width=500, height=250)

# %% [markdown]
# > **Meet [Sebastian](https://twitter.com/dog_rates/status/874012996292530176), an example of a puppo.**
# <img src="https://pbs.twimg.com/media/DCEeLxjXsAAvNSM.jpg" alt='A Puppo' width="400"/>

# %% [markdown]
# ### 3. Favorite dog breed
# > **As given in Fig. 3 below, 5 Highly rated dog breeds include:**
# 1. Golden Retriever
# 2. Labrador Retriever
# 3. Pembroke
# 4. Chihuahua
# 5. French Bulldog
#
# > According to the American Kernel Club article [The 25 Most Popular Dog Breeds of 2023](https://www.akc.org/expert-advice/dog-breeds/most-popular-dog-breeds-of-2021/), Golden Retriever and Labarador Retriever are part of the top 5 most popular and must love dog breeds.Golden and Labrador Retrievers can be trained as guide dogs and therapy dogs, and may compete in obedience trials and other dog sports. They are happy and outgoing and love to retrieve balls, frisbees and just about anything you toss out. No wonder these dog breeds are the most loved.

# %%
display.Image("./images/breed_rating.png", embed=True, width=500, height=250)

# %% [markdown]
# > This is Stuart (a Golden Retriever) and Goose (a Labarador Retriever), examples of favorite Golden Retriever and Labarador Retriever.
#
# Golden Retriever | Labarador Retriever
# - | -
# <img src="https://pbs.twimg.com/media/DFg_2PVW0AEHN3p.jpg" alt="A Golden Retriever" width="300"/> | <img src="https://pbs.twimg.com/media/DCdH8YpUQAAiEbL.jpg" alt="A Labrador Retriever" width="300"/>

# %% [markdown]
# ### 4. Relationship between likes and retweets
# > A strong Correlation (Spearman's rho: 0.93) between retweets and likes among all the tweets in the sample, shows a strong relationship. Fig. 4 points to the same thought.

# %%
display.Image("./images/retweet_vs_favorite.png", embed=True, width=500, height=250)

# %% [markdown]
# ### 5. Device a tweet was tweeted from.
#
# > Most twitter activity on the WeRateDogs twitter account is accessed via twitter for iphone app followed by Twitter Web Client.
# > [Elon Musk](https://twitter.com/elonmusk/status/1592178009410531330?ref_src=twsrc%5Etfw%7Ctwcamp%5Etweetembed%7Ctwterm%5E1592178009410531330%7Ctwgr%5E22544b7f286b04b41484a4b83cd408e871abc0a3%7Ctwcon%5Es1_&ref_url=https%3A%2F%2Fappleinsider.com%2Farticles%2F22%2F11%2F14%2Ftwitter-kills-off-twitter-for-iphone-message-and-spoils-everyones-fun) the new owner of Twitter suggested removing the line that says what device a tweet was tweeted.

# %%
display.Image("./images/source_count.png", embed=True, width=400, height=200)

# %% [markdown]
# ## Conclusions
#
# > 1. The popular dog names are Charlie, Cooper, Oliver, Lucy and Sadie.
# 2. Puppos are the most retweeted and favorite dog stage.
# 3. 5 most loved dog breeds include the Golden Retriever, Labrador Retriever, Pembroke, Chihuahua and French Bulldog.
# 4. Favorite dogs are likely to be highly retweeted.
# 5. The popular device in WeRateDog twitter activity is Twitter for Iphone however this device label will be removed from the Twitter app as suggested by Twitter new owner Elon Must in 2022.
#
# ### Disclaimer
# > Assessing and cleaning the entire dataset completely would require a lot of time, and was not necessary to practice and demonstrate skills in data wrangling. Therefore, the requirements of this project were only to assess and clean at least 8 quality issues and at least 2 tidiness issues in this dataset.
